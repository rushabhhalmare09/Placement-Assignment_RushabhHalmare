# %% [markdown]
# ### Question - 1
# A Social Media Influencer collected data on Facebook friend requests and used
# a supervised algorithm to predict whether a user would accept a friend request or
# not. Dataset This is the Dataset You can use this dataset for this question. Note : Use
# only Dask and Use MLflow

# %%
import dask.dataframe as dd
from dask_ml.model_selection import train_test_split
from dask_ml.linear_model import LogisticRegression
import mlflow
import mlflow.sklearn
import networkx as nx

# %%
import zipfile

# Unzip the file
with zipfile.ZipFile("/content/drive/MyDrive/ML/ADVANCE/ADV_ML_Q1/train.csv.zip", "r") as zip_ref:
    zip_ref.extractall("/content/")

# %%
mlflow.start_run(nested=True)
# Out:
# <ActiveRun: >

# %%
df = dd.read_csv("/content/train.csv")

# %%
df.head()
# Out:
#    source_node  destination_node
# 0            1            690569
# 1            1            315892
# 2            1            189226
# 3            2            834328
# 4            2           1615927

# %%
# Convert the source and destination nodes to Dask arrays
source_nodes = df['source_node'].to_dask_array(lengths=True)
destination_nodes = df['destination_node'].to_dask_array(lengths=True)

# Create a directed graph using NetworkX
G = nx.DiGraph()
edges = [(source, destination) for source, destination in zip(source_nodes.compute(), destination_nodes.compute())]
G.add_edges_from(edges)

# %%
# Calculate Common Neighbors
def common_neighbors_score(G, u, v):
    common_neighbors = set(G.successors(u)).intersection(G.successors(v))
    return len(common_neighbors)

# %%
# Calculate Jaccard's Coefficient
def jaccard_coefficient_score(G, u, v):
    u_neighbors = set(G.successors(u))
    v_neighbors = set(G.successors(v))
    intersection = u_neighbors.intersection(v_neighbors)
    union = u_neighbors.union(v_neighbors)
    return len(intersection) / len(union)

# %%
# Calculate Preferential Attachment
def preferential_attachment_score(G, u, v):
    u_neighbors = set(G.successors(u))
    v_neighbors = set(G.successors(v))
    return len(u_neighbors) * len(v_neighbors)

# %%
# Calculate scores for all pairs of nodes
for u, v in G.edges():
    common_neighbors = common_neighbors_score(G, u, v)
    jaccard_coefficient = jaccard_coefficient_score(G, u, v)
    preferential_attachment = preferential_attachment_score(G, u, v)
    
    # Log scores and other relevant information using MLflow
    with mlflow.start_run(nested=True):
        mlflow.log_param("Source Node", u)
        mlflow.log_param("Destination Node", v)
        mlflow.log_metric("Common Neighbors Score", common_neighbors)
        mlflow.log_metric("Preferential Attachment Score", preferential_attachment)
    
    print(f"Nodes {u} and {v}:")
    print(f"Common Neighbors Score: {common_neighbors}")
    print(f"Jaccard's Coefficient Score: {jaccard_coefficient}")
    print(f"Preferential Attachment Score: {preferential_attachment}")
    print("-------------")

# End the MLflow run
mlflow.end_run()
# Out:
# Streaming output truncated to the last 5000 lines.
# Nodes 946366 and 84:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.023255813953488372
# Preferential Attachment Score: 483
# -------------
# Nodes 946366 and 1572098:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.15151515151515152
# Preferential Attachment Score: 345
# -------------
# Nodes 946366 and 995833:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.03571428571428571
# Preferential Attachment Score: 138
# -------------
# Nodes 946366 and 1117552:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.03225806451612903
# Preferential Attachment Score: 207
# -------------
# Nodes 946366 and 1202832:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.07142857142857142
# Preferential Attachment Score: 161
# -------------
# Nodes 164496 and 20582:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 72
# -------------
# Nodes 164496 and 913164:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 164496 and 1189814:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.047619047619047616
# Preferential Attachment Score: 1008
# -------------
# Nodes 164496 and 1619627:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.13157894736842105
# Preferential Attachment Score: 456
# -------------
# Nodes 164496 and 242218:
# Common Neighbors Score: 9
# Jaccard's Coefficient Score: 0.1323529411764706
# Preferential Attachment Score: 1272
# -------------
# Nodes 164496 and 1517397:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.030303030303030304
# Preferential Attachment Score: 240
# -------------
# Nodes 164496 and 1217069:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 768
# -------------
# Nodes 164496 and 1378118:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.010638297872340425
# Preferential Attachment Score: 1704
# -------------
# Nodes 164496 and 1023728:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.03571428571428571
# Preferential Attachment Score: 816
# -------------
# Nodes 164496 and 599849:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.018518518518518517
# Preferential Attachment Score: 744
# -------------
# Nodes 164496 and 447831:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.035398230088495575
# Preferential Attachment Score: 2232
# -------------
# Nodes 164496 and 496397:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 552
# -------------
# Nodes 164496 and 544614:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.02127659574468085
# Preferential Attachment Score: 576
# -------------
# Nodes 164496 and 1767391:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 216
# -------------
# Nodes 164496 and 1362510:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.12195121951219512
# Preferential Attachment Score: 528
# -------------
# Nodes 164496 and 84:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.07142857142857142
# Preferential Attachment Score: 504
# -------------
# Nodes 164496 and 272183:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.016666666666666666
# Preferential Attachment Score: 888
# -------------
# Nodes 164496 and 973278:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.03571428571428571
# Preferential Attachment Score: 120
# -------------
# Nodes 164496 and 473699:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.06451612903225806
# Preferential Attachment Score: 216
# -------------
# Nodes 164496 and 574304:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.06896551724137931
# Preferential Attachment Score: 168
# -------------
# Nodes 164496 and 585424:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.02564102564102564
# Preferential Attachment Score: 384
# -------------
# Nodes 164496 and 1686333:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.05454545454545454
# Preferential Attachment Score: 816
# -------------
# Nodes 164496 and 244887:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.09302325581395349
# Preferential Attachment Score: 552
# -------------
# Nodes 164496 and 1611527:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 941898 and 212129:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.03389830508474576
# Preferential Attachment Score: 888
# -------------
# Nodes 941898 and 183951:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 1628
# -------------
# Nodes 941898 and 1006399:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 592
# -------------
# Nodes 941898 and 1530112:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.04
# Preferential Attachment Score: 2479
# -------------
# Nodes 941898 and 1363853:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 999
# -------------
# Nodes 941898 and 22034:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.09433962264150944
# Preferential Attachment Score: 777
# -------------
# Nodes 941898 and 983223:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.022988505747126436
# Preferential Attachment Score: 1924
# -------------
# Nodes 941898 and 1465480:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 370
# -------------
# Nodes 941898 and 109429:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.03571428571428571
# Preferential Attachment Score: 777
# -------------
# Nodes 941898 and 398464:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.05263157894736842
# Preferential Attachment Score: 1591
# -------------
# Nodes 941898 and 1619627:
# Common Neighbors Score: 9
# Jaccard's Coefficient Score: 0.19148936170212766
# Preferential Attachment Score: 703
# -------------
# Nodes 941898 and 489480:
# Common Neighbors Score: 12
# Jaccard's Coefficient Score: 0.16666666666666666
# Preferential Attachment Score: 1739
# -------------
# Nodes 941898 and 1703459:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 222
# -------------
# Nodes 941898 and 161441:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 259
# -------------
# Nodes 941898 and 1107624:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.015873015873015872
# Preferential Attachment Score: 999
# -------------
# Nodes 941898 and 1123422:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.0064516129032258064
# Preferential Attachment Score: 4403
# -------------
# Nodes 941898 and 1218496:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.09375
# Preferential Attachment Score: 1221
# -------------
# Nodes 941898 and 623534:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.05454545454545454
# Preferential Attachment Score: 777
# -------------
# Nodes 941898 and 1324821:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.03571428571428571
# Preferential Attachment Score: 777
# -------------
# Nodes 941898 and 979541:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.07142857142857142
# Preferential Attachment Score: 1406
# -------------
# Nodes 941898 and 411461:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.01904761904761905
# Preferential Attachment Score: 2590
# -------------
# Nodes 941898 and 447831:
# Common Neighbors Score: 7
# Jaccard's Coefficient Score: 0.056910569105691054
# Preferential Attachment Score: 3441
# -------------
# Nodes 941898 and 920495:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 962
# -------------
# Nodes 941898 and 900663:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.09090909090909091
# Preferential Attachment Score: 1295
# -------------
# Nodes 941898 and 800589:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 1147
# -------------
# Nodes 941898 and 1291455:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.02
# Preferential Attachment Score: 518
# -------------
# Nodes 941898 and 1362510:
# Common Neighbors Score: 10
# Jaccard's Coefficient Score: 0.20408163265306123
# Preferential Attachment Score: 814
# -------------
# Nodes 941898 and 84:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.07407407407407407
# Preferential Attachment Score: 777
# -------------
# Nodes 941898 and 1144346:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.02
# Preferential Attachment Score: 518
# -------------
# Nodes 941898 and 731698:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 941898 and 575740:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 296
# -------------
# Nodes 941898 and 608267:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.019230769230769232
# Preferential Attachment Score: 592
# -------------
# Nodes 941898 and 1686333:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.09230769230769231
# Preferential Attachment Score: 1258
# -------------
# Nodes 941898 and 244887:
# Common Neighbors Score: 8
# Jaccard's Coefficient Score: 0.15384615384615385
# Preferential Attachment Score: 851
# -------------
# Nodes 941898 and 1741238:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 111
# -------------
# Nodes 941898 and 1026414:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.14634146341463414
# Preferential Attachment Score: 370
# -------------
# Nodes 941898 and 996907:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.08333333333333333
# Preferential Attachment Score: 555
# -------------
# Nodes 447831 and 900414:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 2697
# -------------
# Nodes 447831 and 930504:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 651
# -------------
# Nodes 447831 and 1843512:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 1116
# -------------
# Nodes 447831 and 445815:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 1302
# -------------
# Nodes 447831 and 759964:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 8370
# -------------
# Nodes 447831 and 1168115:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.009259259259259259
# Preferential Attachment Score: 1488
# -------------
# Nodes 447831 and 786387:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 186
# -------------
# Nodes 447831 and 1472729:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.024793388429752067
# Preferential Attachment Score: 2883
# -------------
# Nodes 447831 and 1144152:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 2511
# -------------
# Nodes 447831 and 1295223:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 558
# -------------
# Nodes 447831 and 1189814:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.015037593984962405
# Preferential Attachment Score: 3906
# -------------
# Nodes 447831 and 1698938:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.02857142857142857
# Preferential Attachment Score: 1395
# -------------
# Nodes 447831 and 1486462:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.011320754716981131
# Preferential Attachment Score: 16275
# -------------
# Nodes 447831 and 1492031:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.010638297872340425
# Preferential Attachment Score: 186
# -------------
# Nodes 447831 and 824163:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.009900990099009901
# Preferential Attachment Score: 837
# -------------
# Nodes 447831 and 109429:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.017857142857142856
# Preferential Attachment Score: 1953
# -------------
# Nodes 447831 and 1255626:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.023809523809523808
# Preferential Attachment Score: 3348
# -------------
# Nodes 447831 and 1306704:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.034482758620689655
# Preferential Attachment Score: 2511
# -------------
# Nodes 447831 and 1454697:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.026143790849673203
# Preferential Attachment Score: 5952
# -------------
# Nodes 447831 and 1619627:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.05660377358490566
# Preferential Attachment Score: 1767
# -------------
# Nodes 447831 and 716600:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.05309734513274336
# Preferential Attachment Score: 2418
# -------------
# Nodes 447831 and 1486758:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.007692307692307693
# Preferential Attachment Score: 3534
# -------------
# Nodes 447831 and 489480:
# Common Neighbors Score: 10
# Jaccard's Coefficient Score: 0.07692307692307693
# Preferential Attachment Score: 4371
# -------------
# Nodes 447831 and 1747250:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.03125
# Preferential Attachment Score: 3627
# -------------
# Nodes 447831 and 749965:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 744
# -------------
# Nodes 447831 and 112078:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 1674
# -------------
# Nodes 447831 and 1107624:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.034482758620689655
# Preferential Attachment Score: 2511
# -------------
# Nodes 447831 and 1747582:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.022556390977443608
# Preferential Attachment Score: 3999
# -------------
# Nodes 447831 and 587009:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.018518518518518517
# Preferential Attachment Score: 1581
# -------------
# Nodes 447831 and 857107:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.019417475728155338
# Preferential Attachment Score: 1116
# -------------
# Nodes 447831 and 609740:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 4092
# -------------
# Nodes 447831 and 988700:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 1767
# -------------
# Nodes 447831 and 264864:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.031746031746031744
# Preferential Attachment Score: 3441
# -------------
# Nodes 447831 and 164496:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.035398230088495575
# Preferential Attachment Score: 2232
# -------------
# Nodes 447831 and 667640:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.009433962264150943
# Preferential Attachment Score: 1302
# -------------
# Nodes 447831 and 1550208:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.04201680672268908
# Preferential Attachment Score: 2883
# -------------
# Nodes 447831 and 650999:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.04838709677419355
# Preferential Attachment Score: 3441
# -------------
# Nodes 447831 and 941898:
# Common Neighbors Score: 7
# Jaccard's Coefficient Score: 0.056910569105691054
# Preferential Attachment Score: 3441
# -------------
# Nodes 447831 and 545966:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.021739130434782608
# Preferential Attachment Score: 4464
# -------------
# Nodes 447831 and 1799184:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.014184397163120567
# Preferential Attachment Score: 4650
# -------------
# Nodes 447831 and 1550604:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 93
# -------------
# Nodes 447831 and 920495:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.02586206896551724
# Preferential Attachment Score: 2418
# -------------
# Nodes 447831 and 1576503:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 837
# -------------
# Nodes 447831 and 1663110:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.008403361344537815
# Preferential Attachment Score: 2511
# -------------
# Nodes 447831 and 336907:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 465
# -------------
# Nodes 447831 and 1731167:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.023255813953488372
# Preferential Attachment Score: 3627
# -------------
# Nodes 447831 and 1478849:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 3627
# -------------
# Nodes 447831 and 1362510:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.05504587155963303
# Preferential Attachment Score: 2046
# -------------
# Nodes 447831 and 84:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.05555555555555555
# Preferential Attachment Score: 1953
# -------------
# Nodes 447831 and 1465877:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.043795620437956206
# Preferential Attachment Score: 4650
# -------------
# Nodes 447831 and 226892:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 372
# -------------
# Nodes 447831 and 1354719:
# Common Neighbors Score: 7
# Jaccard's Coefficient Score: 0.06862745098039216
# Preferential Attachment Score: 1488
# -------------
# Nodes 447831 and 1383519:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.058823529411764705
# Preferential Attachment Score: 1395
# -------------
# Nodes 447831 and 762568:
# Common Neighbors Score: 9
# Jaccard's Coefficient Score: 0.08490566037735849
# Preferential Attachment Score: 2046
# -------------
# Nodes 447831 and 576792:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.008695652173913044
# Preferential Attachment Score: 2139
# -------------
# Nodes 447831 and 1194031:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.03225806451612903
# Preferential Attachment Score: 3255
# -------------
# Nodes 447831 and 826536:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.008928571428571428
# Preferential Attachment Score: 1860
# -------------
# Nodes 447831 and 507275:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.015267175572519083
# Preferential Attachment Score: 3720
# -------------
# Nodes 447831 and 363069:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 372
# -------------
# Nodes 447831 and 1831225:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.010101010101010102
# Preferential Attachment Score: 651
# -------------
# Nodes 447831 and 933268:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.008695652173913044
# Preferential Attachment Score: 2139
# -------------
# Nodes 447831 and 418898:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 1860
# -------------
# Nodes 447831 and 1246585:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.017094017094017096
# Preferential Attachment Score: 2418
# -------------
# Nodes 447831 and 720709:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.008928571428571428
# Preferential Attachment Score: 1860
# -------------
# Nodes 447831 and 1288252:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 465
# -------------
# Nodes 447831 and 1572098:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.02857142857142857
# Preferential Attachment Score: 1395
# -------------
# Nodes 447831 and 1345368:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.008695652173913044
# Preferential Attachment Score: 2139
# -------------
# Nodes 447831 and 1043274:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.017391304347826087
# Preferential Attachment Score: 2232
# -------------
# Nodes 447831 and 484439:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 372
# -------------
# Nodes 447831 and 1546951:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.02727272727272727
# Preferential Attachment Score: 1860
# -------------
# Nodes 447831 and 1003890:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 279
# -------------
# Nodes 447831 and 419220:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 447831 and 358213:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 1395
# -------------
# Nodes 447831 and 1208112:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.02702702702702703
# Preferential Attachment Score: 1953
# -------------
# Nodes 447831 and 1420660:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.01652892561983471
# Preferential Attachment Score: 2790
# -------------
# Nodes 447831 and 245052:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 279
# -------------
# Nodes 447831 and 851411:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.010101010101010102
# Preferential Attachment Score: 651
# -------------
# Nodes 447831 and 965303:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.0297029702970297
# Preferential Attachment Score: 1023
# -------------
# Nodes 447831 and 1168686:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 465
# -------------
# Nodes 447831 and 1029900:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 1581
# -------------
# Nodes 447831 and 207715:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.01020408163265306
# Preferential Attachment Score: 558
# -------------
# Nodes 447831 and 349201:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.020833333333333332
# Preferential Attachment Score: 465
# -------------
# Nodes 447831 and 1448713:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.029411764705882353
# Preferential Attachment Score: 1116
# -------------
# Nodes 447831 and 1122405:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 93
# -------------
# Nodes 447831 and 751223:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.030612244897959183
# Preferential Attachment Score: 744
# -------------
# Nodes 447831 and 877757:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.010416666666666666
# Preferential Attachment Score: 372
# -------------
# Nodes 447831 and 791503:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 2046
# -------------
# Nodes 447831 and 90034:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.010752688172043012
# Preferential Attachment Score: 93
# -------------
# Nodes 447831 and 985033:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 93
# -------------
# Nodes 447831 and 101703:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.010638297872340425
# Preferential Attachment Score: 186
# -------------
# Nodes 447831 and 344916:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.010526315789473684
# Preferential Attachment Score: 279
# -------------
# Nodes 447831 and 1470163:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 93
# -------------
# Nodes 447831 and 920531:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 93
# -------------
# Nodes 1362510 and 22034:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.10256410256410256
# Preferential Attachment Score: 462
# -------------
# Nodes 1362510 and 628304:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.024096385542168676
# Preferential Attachment Score: 1386
# -------------
# Nodes 1362510 and 1619627:
# Common Neighbors Score: 7
# Jaccard's Coefficient Score: 0.20588235294117646
# Preferential Attachment Score: 418
# -------------
# Nodes 1362510 and 113445:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 198
# -------------
# Nodes 1362510 and 489480:
# Common Neighbors Score: 9
# Jaccard's Coefficient Score: 0.15
# Preferential Attachment Score: 1034
# -------------
# Nodes 1362510 and 1182549:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.012048192771084338
# Preferential Attachment Score: 1364
# -------------
# Nodes 1362510 and 1378118:
# Common Neighbors Score: 7
# Jaccard's Coefficient Score: 0.08139534883720931
# Preferential Attachment Score: 1562
# -------------
# Nodes 1362510 and 164496:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.12195121951219512
# Preferential Attachment Score: 528
# -------------
# Nodes 1362510 and 1218496:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.057692307692307696
# Preferential Attachment Score: 726
# -------------
# Nodes 1362510 and 169353:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.05128205128205128
# Preferential Attachment Score: 418
# -------------
# Nodes 1362510 and 1719182:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.07317073170731707
# Preferential Attachment Score: 484
# -------------
# Nodes 1362510 and 623534:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.10256410256410256
# Preferential Attachment Score: 462
# -------------
# Nodes 1362510 and 1324821:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.075
# Preferential Attachment Score: 462
# -------------
# Nodes 1362510 and 941898:
# Common Neighbors Score: 10
# Jaccard's Coefficient Score: 0.20408163265306123
# Preferential Attachment Score: 814
# -------------
# Nodes 1362510 and 1799184:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.02857142857142857
# Preferential Attachment Score: 1100
# -------------
# Nodes 1362510 and 447831:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.05504587155963303
# Preferential Attachment Score: 2046
# -------------
# Nodes 1362510 and 545850:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 462
# -------------
# Nodes 1362510 and 84:
# Common Neighbors Score: 7
# Jaccard's Coefficient Score: 0.19444444444444445
# Preferential Attachment Score: 462
# -------------
# Nodes 1362510 and 312244:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.019230769230769232
# Preferential Attachment Score: 682
# -------------
# Nodes 1362510 and 1442424:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 242
# -------------
# Nodes 1362510 and 244887:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.125
# Preferential Attachment Score: 506
# -------------
# Nodes 1362510 and 1026414:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.23076923076923078
# Preferential Attachment Score: 220
# -------------
# Nodes 1354719 and 1454697:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.03896103896103896
# Preferential Attachment Score: 1024
# -------------
# Nodes 1354719 and 716600:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.16666666666666666
# Preferential Attachment Score: 416
# -------------
# Nodes 1354719 and 561061:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.11538461538461539
# Preferential Attachment Score: 208
# -------------
# Nodes 1354719 and 411461:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.04878048780487805
# Preferential Attachment Score: 1120
# -------------
# Nodes 1354719 and 447831:
# Common Neighbors Score: 7
# Jaccard's Coefficient Score: 0.06862745098039216
# Preferential Attachment Score: 1488
# -------------
# Nodes 1354719 and 884529:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.04
# Preferential Attachment Score: 576
# -------------
# Nodes 1354719 and 84:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.05714285714285714
# Preferential Attachment Score: 336
# -------------
# Nodes 1354719 and 1465877:
# Common Neighbors Score: 7
# Jaccard's Coefficient Score: 0.11864406779661017
# Preferential Attachment Score: 800
# -------------
# Nodes 1354719 and 1725166:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.17391304347826086
# Preferential Attachment Score: 176
# -------------
# Nodes 1354719 and 1383519:
# Common Neighbors Score: 13
# Jaccard's Coefficient Score: 0.7222222222222222
# Preferential Attachment Score: 240
# -------------
# Nodes 1354719 and 762568:
# Common Neighbors Score: 13
# Jaccard's Coefficient Score: 0.52
# Preferential Attachment Score: 352
# -------------
# Nodes 1354719 and 781880:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.058823529411764705
# Preferential Attachment Score: 320
# -------------
# Nodes 1354719 and 1524014:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.07407407407407407
# Preferential Attachment Score: 672
# -------------
# Nodes 1354719 and 1394548:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.10810810810810811
# Preferential Attachment Score: 400
# -------------
# Nodes 1354719 and 1525440:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 1354719 and 751223:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.14285714285714285
# Preferential Attachment Score: 128
# -------------
# Nodes 1498955 and 1397268:
# Common Neighbors Score: 8
# Jaccard's Coefficient Score: 0.17391304347826086
# Preferential Attachment Score: 729
# -------------
# Nodes 1498955 and 1784991:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.03389830508474576
# Preferential Attachment Score: 918
# -------------
# Nodes 1498955 and 626377:
# Common Neighbors Score: 8
# Jaccard's Coefficient Score: 0.13559322033898305
# Preferential Attachment Score: 1080
# -------------
# Nodes 1498955 and 900213:
# Common Neighbors Score: 15
# Jaccard's Coefficient Score: 0.3125
# Preferential Attachment Score: 972
# -------------
# Nodes 1498955 and 889216:
# Common Neighbors Score: 9
# Jaccard's Coefficient Score: 0.1836734693877551
# Preferential Attachment Score: 837
# -------------
# Nodes 1498955 and 713289:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.12
# Preferential Attachment Score: 783
# -------------
# Nodes 1498955 and 1446426:
# Common Neighbors Score: 9
# Jaccard's Coefficient Score: 0.2727272727272727
# Preferential Attachment Score: 405
# -------------
# Nodes 1498955 and 925233:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.06976744186046512
# Preferential Attachment Score: 513
# -------------
# Nodes 1498955 and 756167:
# Common Neighbors Score: 10
# Jaccard's Coefficient Score: 0.3125
# Preferential Attachment Score: 405
# -------------
# Nodes 1498955 and 1727048:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.1935483870967742
# Preferential Attachment Score: 270
# -------------
# Nodes 1498955 and 1020554:
# Common Neighbors Score: 8
# Jaccard's Coefficient Score: 0.23529411764705882
# Preferential Attachment Score: 405
# -------------
# Nodes 1498955 and 1344428:
# Common Neighbors Score: 7
# Jaccard's Coefficient Score: 0.22580645161290322
# Preferential Attachment Score: 297
# -------------
# Nodes 1498955 and 1274152:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.10526315789473684
# Preferential Attachment Score: 405
# -------------
# Nodes 1498955 and 1033784:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.01818181818181818
# Preferential Attachment Score: 783
# -------------
# Nodes 1498955 and 924545:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.17142857142857143
# Preferential Attachment Score: 378
# -------------
# Nodes 1498955 and 521058:
# Common Neighbors Score: 8
# Jaccard's Coefficient Score: 0.21052631578947367
# Preferential Attachment Score: 513
# -------------
# Nodes 1498955 and 494975:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.012987012987012988
# Preferential Attachment Score: 1377
# -------------
# Nodes 1498955 and 1377506:
# Common Neighbors Score: 9
# Jaccard's Coefficient Score: 0.2647058823529412
# Preferential Attachment Score: 432
# -------------
# Nodes 1498955 and 1856254:
# Common Neighbors Score: 10
# Jaccard's Coefficient Score: 0.2702702702702703
# Preferential Attachment Score: 540
# -------------
# Nodes 1498955 and 533276:
# Common Neighbors Score: 10
# Jaccard's Coefficient Score: 0.2702702702702703
# Preferential Attachment Score: 540
# -------------
# Nodes 1498955 and 924718:
# Common Neighbors Score: 12
# Jaccard's Coefficient Score: 0.2926829268292683
# Preferential Attachment Score: 702
# -------------
# Nodes 1498955 and 636719:
# Common Neighbors Score: 11
# Jaccard's Coefficient Score: 0.3235294117647059
# Preferential Attachment Score: 486
# -------------
# Nodes 1498955 and 1169229:
# Common Neighbors Score: 8
# Jaccard's Coefficient Score: 0.24242424242424243
# Preferential Attachment Score: 378
# -------------
# Nodes 1498955 and 340727:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.11764705882352941
# Preferential Attachment Score: 297
# -------------
# Nodes 1498955 and 1561544:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 189
# -------------
# Nodes 1498955 and 1200655:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.027777777777777776
# Preferential Attachment Score: 270
# -------------
# Nodes 1498955 and 475940:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.058823529411764705
# Preferential Attachment Score: 243
# -------------
# Nodes 1125968 and 1703647:
# Common Neighbors Score: 7
# Jaccard's Coefficient Score: 0.1320754716981132
# Preferential Attachment Score: 836
# -------------
# Nodes 1125968 and 434689:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 308
# -------------
# Nodes 1125968 and 808382:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.022727272727272728
# Preferential Attachment Score: 506
# -------------
# Nodes 1125968 and 1831501:
# Common Neighbors Score: 18
# Jaccard's Coefficient Score: 0.3157894736842105
# Preferential Attachment Score: 1166
# -------------
# Nodes 1125968 and 626377:
# Common Neighbors Score: 12
# Jaccard's Coefficient Score: 0.24
# Preferential Attachment Score: 880
# -------------
# Nodes 1125968 and 495318:
# Common Neighbors Score: 8
# Jaccard's Coefficient Score: 0.1568627450980392
# Preferential Attachment Score: 814
# -------------
# Nodes 1125968 and 1110477:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.14634146341463414
# Preferential Attachment Score: 550
# -------------
# Nodes 1125968 and 219656:
# Common Neighbors Score: 9
# Jaccard's Coefficient Score: 0.16071428571428573
# Preferential Attachment Score: 946
# -------------
# Nodes 1125968 and 1812006:
# Common Neighbors Score: 7
# Jaccard's Coefficient Score: 0.22580645161290322
# Preferential Attachment Score: 352
# -------------
# Nodes 1125968 and 246138:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.16666666666666666
# Preferential Attachment Score: 440
# -------------
# Nodes 1125968 and 270135:
# Common Neighbors Score: 8
# Jaccard's Coefficient Score: 0.25806451612903225
# Preferential Attachment Score: 374
# -------------
# Nodes 1125968 and 1835334:
# Common Neighbors Score: 7
# Jaccard's Coefficient Score: 0.175
# Preferential Attachment Score: 550
# -------------
# Nodes 1125968 and 889216:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.1276595744680851
# Preferential Attachment Score: 682
# -------------
# Nodes 1125968 and 1177630:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.09302325581395349
# Preferential Attachment Score: 550
# -------------
# Nodes 1125968 and 1018205:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.1111111111111111
# Preferential Attachment Score: 396
# -------------
# Nodes 1125968 and 84:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.10256410256410256
# Preferential Attachment Score: 462
# -------------
# Nodes 1125968 and 1465877:
# Common Neighbors Score: 7
# Jaccard's Coefficient Score: 0.1076923076923077
# Preferential Attachment Score: 1100
# -------------
# Nodes 1125968 and 1394548:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.09302325581395349
# Preferential Attachment Score: 550
# -------------
# Nodes 1125968 and 44869:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.13513513513513514
# Preferential Attachment Score: 440
# -------------
# Nodes 1125968 and 944075:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 1125968 and 1228983:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.08333333333333333
# Preferential Attachment Score: 88
# -------------
# Nodes 1125968 and 674563:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 244887 and 1619627:
# Common Neighbors Score: 7
# Jaccard's Coefficient Score: 0.2
# Preferential Attachment Score: 437
# -------------
# Nodes 244887 and 489480:
# Common Neighbors Score: 11
# Jaccard's Coefficient Score: 0.1864406779661017
# Preferential Attachment Score: 1081
# -------------
# Nodes 244887 and 1690356:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.041666666666666664
# Preferential Attachment Score: 621
# -------------
# Nodes 244887 and 164496:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.09302325581395349
# Preferential Attachment Score: 552
# -------------
# Nodes 244887 and 1587590:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.019230769230769232
# Preferential Attachment Score: 690
# -------------
# Nodes 244887 and 941898:
# Common Neighbors Score: 8
# Jaccard's Coefficient Score: 0.15384615384615385
# Preferential Attachment Score: 851
# -------------
# Nodes 244887 and 1362510:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.125
# Preferential Attachment Score: 506
# -------------
# Nodes 244887 and 84:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.1282051282051282
# Preferential Attachment Score: 483
# -------------
# Nodes 244887 and 1725166:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 253
# -------------
# Nodes 244887 and 731698:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 244887 and 608267:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.05405405405405406
# Preferential Attachment Score: 368
# -------------
# Nodes 244887 and 1043274:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.06818181818181818
# Preferential Attachment Score: 552
# -------------
# Nodes 244887 and 976035:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 138
# -------------
# Nodes 244887 and 1686333:
# Common Neighbors Score: 12
# Jaccard's Coefficient Score: 0.26666666666666666
# Preferential Attachment Score: 782
# -------------
# Nodes 244887 and 906634:
# Common Neighbors Score: 7
# Jaccard's Coefficient Score: 0.19444444444444445
# Preferential Attachment Score: 460
# -------------
# Nodes 244887 and 1054946:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.08108108108108109
# Preferential Attachment Score: 391
# -------------
# Nodes 244887 and 636422:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 244887 and 996907:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.11764705882352941
# Preferential Attachment Score: 345
# -------------
# Nodes 244887 and 210707:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.02564102564102564
# Preferential Attachment Score: 391
# -------------
# Nodes 244887 and 443342:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 115
# -------------
# Nodes 244887 and 1195936:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.041666666666666664
# Preferential Attachment Score: 46
# -------------
# Nodes 244887 and 289357:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 46
# -------------
# Nodes 244887 and 521073:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 23
# -------------
# Nodes 751223 and 1609244:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 152
# -------------
# Nodes 751223 and 561061:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.05
# Preferential Attachment Score: 104
# -------------
# Nodes 751223 and 667640:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 112
# -------------
# Nodes 751223 and 941898:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.046511627906976744
# Preferential Attachment Score: 296
# -------------
# Nodes 751223 and 447831:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.030612244897959183
# Preferential Attachment Score: 744
# -------------
# Nodes 751223 and 1354719:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.14285714285714285
# Preferential Attachment Score: 128
# -------------
# Nodes 751223 and 781880:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.07692307692307693
# Preferential Attachment Score: 160
# -------------
# Nodes 751223 and 244887:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.03333333333333333
# Preferential Attachment Score: 184
# -------------
# Nodes 1354664 and 1189814:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.0425531914893617
# Preferential Attachment Score: 294
# -------------
# Nodes 1354664 and 1828738:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.0625
# Preferential Attachment Score: 70
# -------------
# Nodes 1354664 and 1289676:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 140
# -------------
# Nodes 1354664 and 84:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 147
# -------------
# Nodes 1354664 and 1499660:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 77
# -------------
# Nodes 1354664 and 171064:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 28
# -------------
# Nodes 1354664 and 1589736:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.1
# Preferential Attachment Score: 28
# -------------
# Nodes 597299 and 1454697:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.014925373134328358
# Preferential Attachment Score: 256
# -------------
# Nodes 597299 and 628304:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 252
# -------------
# Nodes 597299 and 275514:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.02
# Preferential Attachment Score: 392
# -------------
# Nodes 597299 and 84:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.041666666666666664
# Preferential Attachment Score: 84
# -------------
# Nodes 86 and 907649:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 35
# -------------
# Nodes 907649 and 903333:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 560
# -------------
# Nodes 907649 and 870817:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.013513513513513514
# Preferential Attachment Score: 1400
# -------------
# Nodes 907649 and 1180015:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.015625
# Preferential Attachment Score: 1050
# -------------
# Nodes 907649 and 1792852:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.043478260869565216
# Preferential Attachment Score: 455
# -------------
# Nodes 907649 and 1809143:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 875
# -------------
# Nodes 907649 and 787290:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 1925
# -------------
# Nodes 907649 and 981652:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 280
# -------------
# Nodes 907649 and 1794889:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.0392156862745098
# Preferential Attachment Score: 630
# -------------
# Nodes 907649 and 1279986:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.0273972602739726
# Preferential Attachment Score: 1400
# -------------
# Nodes 907649 and 447046:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 1225
# -------------
# Nodes 907649 and 1851731:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 315
# -------------
# Nodes 907649 and 694556:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 175
# -------------
# Nodes 907649 and 1326334:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 735
# -------------
# Nodes 907649 and 765953:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 910
# -------------
# Nodes 907649 and 1780567:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 350
# -------------
# Nodes 907649 and 1657553:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 595
# -------------
# Nodes 907649 and 251804:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.04081632653061224
# Preferential Attachment Score: 560
# -------------
# Nodes 907649 and 1407356:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.025
# Preferential Attachment Score: 1645
# -------------
# Nodes 907649 and 1765735:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 35
# -------------
# Nodes 907649 and 1764692:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.03278688524590164
# Preferential Attachment Score: 980
# -------------
# Nodes 907649 and 258252:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.08108108108108109
# Preferential Attachment Score: 175
# -------------
# Nodes 907649 and 1559876:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.024390243902439025
# Preferential Attachment Score: 245
# -------------
# Nodes 907649 and 1688140:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.022222222222222223
# Preferential Attachment Score: 385
# -------------
# Nodes 907649 and 371090:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 907649 and 974948:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.06
# Preferential Attachment Score: 630
# -------------
# Nodes 907649 and 1220689:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 420
# -------------
# Nodes 907649 and 537837:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 315
# -------------
# Nodes 907649 and 1165279:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 280
# -------------
# Nodes 907649 and 67029:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.08108108108108109
# Preferential Attachment Score: 175
# -------------
# Nodes 907649 and 1431871:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 210
# -------------
# Nodes 907649 and 1517803:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 907649 and 1697278:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 315
# -------------
# Nodes 907649 and 277814:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.08333333333333333
# Preferential Attachment Score: 140
# -------------
# Nodes 907649 and 1202399:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.08333333333333333
# Preferential Attachment Score: 140
# -------------
# Nodes 907649 and 565262:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 35
# -------------
# Nodes 87 and 1194997:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.35294117647058826
# Preferential Attachment Score: 120
# -------------
# Nodes 87 and 1003093:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.2631578947368421
# Preferential Attachment Score: 135
# -------------
# Nodes 87 and 109627:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.29411764705882354
# Preferential Attachment Score: 105
# -------------
# Nodes 87 and 1854354:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 15
# -------------
# Nodes 87 and 454942:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.1724137931034483
# Preferential Attachment Score: 285
# -------------
# Nodes 87 and 521421:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.125
# Preferential Attachment Score: 45
# -------------
# Nodes 87 and 1159153:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 87 and 508650:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.2777777777777778
# Preferential Attachment Score: 120
# -------------
# Nodes 87 and 231172:
# Common Neighbors Score: 5
# ...
# Preferential Attachment Score: 54
# -------------
# Nodes 578479 and 426194:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 36
# -------------
# Nodes 578479 and 1325873:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 24
# -------------
# Nodes 578479 and 4159:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 24
# -------------
# Nodes 578479 and 765333:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 24
# -------------
# Nodes 566519 and 1269961:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 117
# -------------
# Nodes 566519 and 469602:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 65
# -------------
# Nodes 566519 and 1167310:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 273
# -------------
# Nodes 566519 and 461990:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.0967741935483871
# Preferential Attachment Score: 273
# -------------
# Nodes 566519 and 1446958:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 195
# -------------
# Nodes 566519 and 416879:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 234
# -------------
# Nodes 566519 and 49377:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.06896551724137931
# Preferential Attachment Score: 234
# -------------
# Nodes 566519 and 329:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.030303030303030304
# Preferential Attachment Score: 273
# -------------
# Nodes 566519 and 1610874:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.07692307692307693
# Preferential Attachment Score: 195
# -------------
# Nodes 566519 and 1147163:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 104
# -------------
# Nodes 566519 and 35707:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.058823529411764705
# Preferential Attachment Score: 65
# -------------
# Nodes 566519 and 62529:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 39
# -------------
# Nodes 566519 and 1391542:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.045454545454545456
# Preferential Attachment Score: 130
# -------------
# Nodes 45974 and 1635832:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 32
# -------------
# Nodes 45974 and 1373312:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.047619047619047616
# Preferential Attachment Score: 96
# -------------
# Nodes 45974 and 808402:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 96
# -------------
# Nodes 45974 and 43601:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.3333333333333333
# Preferential Attachment Score: 128
# -------------
# Nodes 45974 and 1341969:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.10526315789473684
# Preferential Attachment Score: 80
# -------------
# Nodes 45974 and 1609779:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.23529411764705882
# Preferential Attachment Score: 80
# -------------
# Nodes 45974 and 464988:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.16666666666666666
# Preferential Attachment Score: 80
# -------------
# Nodes 45974 and 1154097:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.06896551724137931
# Preferential Attachment Score: 240
# -------------
# Nodes 45974 and 105:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.041666666666666664
# Preferential Attachment Score: 144
# -------------
# Nodes 45974 and 1423509:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 45974 and 1211982:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.05263157894736842
# Preferential Attachment Score: 64
# -------------
# Nodes 45974 and 1693868:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.02857142857142857
# Preferential Attachment Score: 320
# -------------
# Nodes 45974 and 649636:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.17647058823529413
# Preferential Attachment Score: 64
# -------------
# Nodes 45974 and 251943:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.17647058823529413
# Preferential Attachment Score: 64
# -------------
# Nodes 45974 and 1680175:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 80
# -------------
# Nodes 45974 and 952655:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 144
# -------------
# Nodes 1154097 and 1285128:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.037037037037037035
# Preferential Attachment Score: 195
# -------------
# Nodes 1154097 and 1297117:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 135
# -------------
# Nodes 1154097 and 1495622:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 75
# -------------
# Nodes 1154097 and 45974:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.06896551724137931
# Preferential Attachment Score: 240
# -------------
# Nodes 1154097 and 43601:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.045454545454545456
# Preferential Attachment Score: 120
# -------------
# Nodes 1154097 and 645962:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 45
# -------------
# Nodes 1154097 and 1208107:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 1154097 and 1213415:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 75
# -------------
# Nodes 1154097 and 1068574:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 165
# -------------
# Nodes 1154097 and 1317827:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 90
# -------------
# Nodes 1154097 and 1766921:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.05555555555555555
# Preferential Attachment Score: 60
# -------------
# Nodes 1154097 and 1578058:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 30
# -------------
# Nodes 1154097 and 105:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.09090909090909091
# Preferential Attachment Score: 135
# -------------
# Nodes 1154097 and 304924:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 60
# -------------
# Nodes 1154097 and 16569:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.0625
# Preferential Attachment Score: 30
# -------------
# Nodes 1766921 and 873660:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 184
# -------------
# Nodes 1766921 and 1154097:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.05555555555555555
# Preferential Attachment Score: 60
# -------------
# Nodes 1766921 and 1208107:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 1766921 and 139193:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 1407805 and 1625115:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 1407805 and 566519:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 52
# -------------
# Nodes 1407805 and 1154097:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.05555555555555555
# Preferential Attachment Score: 60
# -------------
# Nodes 1407805 and 105:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.3
# Preferential Attachment Score: 36
# -------------
# Nodes 1418762 and 96747:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 20
# -------------
# Nodes 1418762 and 105:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 45
# -------------
# Nodes 1418762 and 67560:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 20
# -------------
# Nodes 1418762 and 1369659:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 10
# -------------
# Nodes 1418762 and 1628961:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 20
# -------------
# Nodes 1391542 and 578479:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.14285714285714285
# Preferential Attachment Score: 60
# -------------
# Nodes 1391542 and 566519:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.045454545454545456
# Preferential Attachment Score: 130
# -------------
# Nodes 1391542 and 1090482:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 40
# -------------
# Nodes 1391542 and 105:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.11764705882352941
# Preferential Attachment Score: 90
# -------------
# Nodes 1391542 and 619167:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 30
# -------------
# Nodes 1391542 and 35707:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.15384615384615385
# Preferential Attachment Score: 50
# -------------
# Nodes 1391542 and 1767105:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 10
# -------------
# Nodes 1391542 and 1693868:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 200
# -------------
# Nodes 1391542 and 450030:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.08333333333333333
# Preferential Attachment Score: 30
# -------------
# Nodes 1391542 and 897243:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 20
# -------------
# Nodes 106 and 266064:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.05263157894736842
# Preferential Attachment Score: 75
# -------------
# Nodes 106 and 1122174:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 125
# -------------
# Nodes 106 and 1784331:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.2
# Preferential Attachment Score: 35
# -------------
# Nodes 106 and 1266933:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.1
# Preferential Attachment Score: 85
# -------------
# Nodes 106 and 237219:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 266064 and 1243150:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.15789473684210525
# Preferential Attachment Score: 105
# -------------
# Nodes 266064 and 298101:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.1111111111111111
# Preferential Attachment Score: 675
# -------------
# Nodes 266064 and 1333490:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.08108108108108109
# Preferential Attachment Score: 375
# -------------
# Nodes 266064 and 124918:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 690
# -------------
# Nodes 266064 and 1751654:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.05
# Preferential Attachment Score: 90
# -------------
# Nodes 266064 and 245588:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.09090909090909091
# Preferential Attachment Score: 315
# -------------
# Nodes 266064 and 1036154:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.043478260869565216
# Preferential Attachment Score: 135
# -------------
# Nodes 266064 and 994472:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.043478260869565216
# Preferential Attachment Score: 495
# -------------
# Nodes 266064 and 361290:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 165
# -------------
# Nodes 266064 and 467621:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 555
# -------------
# Nodes 266064 and 1824559:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 135
# -------------
# Nodes 266064 and 1024562:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 330
# -------------
# Nodes 266064 and 1266933:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.03225806451612903
# Preferential Attachment Score: 255
# -------------
# Nodes 266064 and 762979:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 135
# -------------
# Nodes 266064 and 1052742:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.022727272727272728
# Preferential Attachment Score: 450
# -------------
# Nodes 1122174 and 1298849:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 750
# -------------
# Nodes 1122174 and 171504:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 250
# -------------
# Nodes 1122174 and 940158:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.10909090909090909
# Preferential Attachment Score: 900
# -------------
# Nodes 1122174 and 1469090:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 2125
# -------------
# Nodes 1122174 and 904578:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.013513513513513514
# Preferential Attachment Score: 1250
# -------------
# Nodes 1122174 and 904072:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.021739130434782608
# Preferential Attachment Score: 550
# -------------
# Nodes 1122174 and 1751654:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.03333333333333333
# Preferential Attachment Score: 150
# -------------
# Nodes 1122174 and 1036154:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.0625
# Preferential Attachment Score: 225
# -------------
# Nodes 1122174 and 946255:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 600
# -------------
# Nodes 1122174 and 582072:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.012658227848101266
# Preferential Attachment Score: 1375
# -------------
# Nodes 1122174 and 840218:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.027777777777777776
# Preferential Attachment Score: 1225
# -------------
# Nodes 1122174 and 1185059:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 725
# -------------
# Nodes 1122174 and 1068949:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.038461538461538464
# Preferential Attachment Score: 50
# -------------
# Nodes 1122174 and 1209307:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.044444444444444446
# Preferential Attachment Score: 550
# -------------
# Nodes 1122174 and 1045821:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 300
# -------------
# Nodes 1122174 and 1425640:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 475
# -------------
# Nodes 1122174 and 1725978:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 425
# -------------
# Nodes 1122174 and 43285:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 200
# -------------
# Nodes 1122174 and 762979:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 225
# -------------
# Nodes 1122174 and 535540:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 75
# -------------
# Nodes 1122174 and 1318255:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 250
# -------------
# Nodes 1122174 and 1086705:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 25
# -------------
# Nodes 1122174 and 106:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 125
# -------------
